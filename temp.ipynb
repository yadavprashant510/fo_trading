# %%
import pandas as pd

# %%
df=pd.read_csv('3mfanddo.csv')
df
# Out:
#          Unnamed: 0 INSTRUMENT     SYMBOL    EXPIRY_DT  STRIKE_PR OPTION_TYP  \
# 0            160393     FUTIDX  BANKNIFTY  29-Aug-2019        0.0         XX
# 1            160394     FUTIDX  BANKNIFTY  26-Sep-2019        0.0         XX
# 2            160395     FUTIDX  BANKNIFTY  31-Oct-2019        0.0         XX
# 3            160396     FUTIDX      NIFTY  29-Aug-2019        0.0         XX
# 4            160397     FUTIDX      NIFTY  26-Sep-2019        0.0         XX
# ...             ...        ...        ...          ...        ...        ...
# 2533205    32769933     OPTSTK       ZEEL  26-Dec-2019      390.0         PE
# 2533206    32769934     OPTSTK       ZEEL  26-Dec-2019      400.0         PE
# 2533207    32769935     OPTSTK       ZEEL  26-Dec-2019      410.0         PE
# 2533208    32769936     OPTSTK       ZEEL  26-Dec-2019      420.0         PE
# 2533209    32769937     OPTSTK       ZEEL  26-Dec-2019      430.0         PE
#
# ...

# %%
df['INSTRUMENT'].value_counts()
# Out:
# INSTRUMENT
# OPTSTK    2152486
# OPTIDX     348752
# FUTSTK      31351
# FUTIDX        621
# Name: count, dtype: int64
